# %% [markdown]
# ## 1. Create you own dataset
# The example below show you how to create your own dataset.
#
# - with import you add the library to notebook, after the import you can use **as** following with an alias
# - strings(alphanumderic) are always placed in within quotes
# -
# - with the  "= { column name [values,values1], column1[...]}" you create your own dataframe
# - pd is the alias of pandas (you can also give it another name)
# - DataFrame is a function within the library panda. You recognize functions by the opening bracket and closing bracket
# - repeating the name of the dataframe show you the dataframe

# %%
import pandas as pd

data = { 'Apples': [1,2,3], 'Banana':[1,2,3,]}

purchases = pd.DataFrame(data)

purchases
# Out:
#    Apples  Banana
# 0       1       1
# 1       2       2
# 2       3       3

# %% [markdown]
# ## 2. import dataset
#
# In the example we read a datafile into a DataFrame and display the data.
#
# **note**
# *
# Important to know is that if the file is not located in the same folder as the runbook, the file must have the full
# location path (including the file and extension) of and must be plased within the brackets.
# *
#
# - the command read_csv('filename') extract the file and put it in a dataframe.
# - the command head() shows the first 5 rows of the dataframe
# - tail shows the last .. rows of the datafrane

# %%
df_food = pd.read_csv('food_coded.csv')
df_food.head()
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
#
#    coffee                      comfort_food        comfort_food_reasons  \
# 0       1                              none       we dont have comfort
# 1       2       chocolate, chips, ice cream        Stress, bored, anger
# 2       2   frozen yogurt, pizza, fast food             stress, sadness
# 3       2  Pizza, Mac and cheese, ice cream                     Boredom
# 4       2      Ice cream, chocolate, chips   Stress, boredom, cravings
#
# ...

# %%
df_food.tail(2)
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 123    3       2          1               720           4.0           420.0
# 124  3.9       1          1               430           NaN           315.0
#
#      coffee                  comfort_food  \
# 123       1  Mac n Cheese, Lasagna, Pizza
# 124       2  Chocolates, pizza, and Ritz.
#
#                               comfort_food_reasons  \
# 123  happiness, they are some of my favorite foods
# 124               hormones, Premenstrual syndrome.
#
#      comfort_food_reasons_coded  ...  soup  sports  thai_food  \
# 123                         NaN  ...   2.0     2.0          1
# 124                         NaN  ...   1.0     2.0          2
#
#     tortilla_calories  turkey_calories  type_sports veggies_day  vitamins  \
# 123             940.0              500          NaN           3         1
# 124             725.0              345          NaN           4         2
#
# ...

# %% [markdown]
# ## 3.  Meta data
# It is also posible to get the Meta Data over the current dataframe **info()** it shows you:
# -  entries in the dataframe
# -  datatype in the dataframe

# %%
df_food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
# GPA                             123 non-null object
# Gender                          125 non-null int64
# breakfast                       125 non-null int64
# calories_chicken                125 non-null int64
# calories_day                    106 non-null float64
# calories_scone                  124 non-null float64
# coffee                          125 non-null int64
# comfort_food                    124 non-null object
# comfort_food_reasons            124 non-null object
# comfort_food_reasons_coded      106 non-null float64
# cook                            122 non-null float64
# comfort_food_reasons_coded.1    125 non-null int64
# cuisine                         108 non-null float64
# diet_current                    124 non-null object
# diet_current_coded              125 non-null int64
# drink                           123 non-null float64
# ...

# %% [markdown]
# describe shows the statistics of the dataframe

# %%
df_food.describe()
# Out:
#            Gender   breakfast  calories_chicken  calories_day  calories_scone  \
# count  125.000000  125.000000        125.000000    106.000000      124.000000
# mean     1.392000    1.112000        577.320000      3.028302      505.241935
# std      0.490161    0.316636        131.214156      0.639308      230.840506
# min      1.000000    1.000000        265.000000      2.000000      315.000000
# 25%      1.000000    1.000000        430.000000      3.000000      420.000000
# 50%      1.000000    1.000000        610.000000      3.000000      420.000000
# 75%      2.000000    1.000000        720.000000      3.000000      420.000000
# max      2.000000    2.000000        720.000000      4.000000      980.000000
#
#           coffee  comfort_food_reasons_coded        cook  \
# count  125.00000                  106.000000  122.000000
# mean     1.75200                    2.698113    2.786885
# std      0.43359                    1.972042    1.038351
# ...

# %% [markdown]
# With correlation you can see how strong the relation is between different column names. 1 is the strongest and zero or below is the weakest
# correlation. The correlation can be use to cherry picking your column names.

# %%
df_food.corr()
# Out:
#                                 Gender  breakfast  calories_chicken  \
# Gender                        1.000000   0.130527         -0.098265
# breakfast                     0.130527   1.000000         -0.029597
# calories_chicken             -0.098265  -0.029597          1.000000
# calories_day                  0.026548  -0.112370          0.420089
# calories_scone                0.154845   0.030659          0.062835
# coffee                       -0.032178  -0.089756          0.159031
# comfort_food_reasons_coded    0.168593   0.017411         -0.068259
# cook                          0.312014  -0.005896         -0.040738
# comfort_food_reasons_coded.1  0.209109   0.018233         -0.009311
# cuisine                       0.102892  -0.050611          0.036199
# diet_current_coded            0.145155   0.111687         -0.148827
# drink                         0.203961   0.213881         -0.032772
# eating_changes_coded          0.037723   0.151237          0.040957
# ...

# %% [markdown]
# ## 4. Null values
# Null values have negative influence on your dataframe. How much impact it has is only visable when you analyze
# the dataframe against the your objective.
# With the **isnull()** you get for every entry with the value **true** if the the value of the cell is empty
# and **false** if the cell in the entry has an value.
#
# With the **.sum()**  you count all the values within that column which has null values.

# %%
df_food.isnull()
df_food.isnull().sum()
# Out:
# GPA                              2
# Gender                           0
# breakfast                        0
# calories_chicken                 0
# calories_day                    19
# calories_scone                   1
# coffee                           0
# comfort_food                     1
# comfort_food_reasons             1
# comfort_food_reasons_coded      19
# cook                             3
# comfort_food_reasons_coded.1     0
# cuisine                         17
# diet_current                     1
# diet_current_coded               0
# drink                            2
# eating_changes                   3
# eating_changes_coded             0
# eating_changes_coded1            0
# eating_out                       0
# employment                       9
# ethnic_food                      0
# exercise                        13
# father_education                 1
# father_profession                3
# fav_cuisine                      2
# fav_cuisine_coded                0
# ...

# %% [markdown]
# To drop null values use the **dropna()** to remove all null values out of your dataframe.

# %%
df_food.dropna()
# Out:
#             GPA  Gender  breakfast  calories_chicken  calories_day  \
# 1         3.654       1          1               610           3.0
# 2           3.3       1          1               720           4.0
# 4           3.5       1          1               720           2.0
# 6           3.8       2          1               610           3.0
# 7           3.3       1          1               720           3.0
# 9           3.3       1          1               430           3.0
# 10          3.5       1          1               610           3.0
# 11        3.904       1          1               720           4.0
# 12          3.4       2          1               430           3.0
# 13          3.6       1          1               610           3.0
# 14          3.1       2          1               610           3.0
# 17          3.6       2          1               430           3.0
# 18          3.4       1          1               720           3.0
# ...

# %%
dataframe.dropna(axis=1)
dataframe.tail(15)

# %% [markdown]
# ## 5. Slice your dataframe
# Not all columns has value for your objective. Columns that has no value for your model can easely removed
# from your dataframe.Remove columns from your dataframe called slicing (like a pie).
# In Python we slice with the open bracket and close braket and the column name.

# %%
coffee = df_food[['coffee','breakfast','Gender']]
coffee.head()
# Out:
#    coffee  breakfast  Gender
# 0       1          1       2
# 1       2          1       1
# 2       2          1       1
# 3       2          1       1
# 4       2          1       1

# %%
coffee.describe()

# %% [markdown]
# ## 6. Filtering your data
# If we only wan't to see the data for men then we need to filter the column **Gender** equal to **men**. To do
# this in python we use the == folowed by the filter you wan't to apply.

# %%
coff = df_food[df_food['Gender'] == 1]
coff = coff[['coffee','breakfast','Gender']]
coff
